# %% [markdown]
# <a href="https://colab.research.google.com/github/axel-sirota/practical-nlp/blob/main/1-synonims/Practical_NLP_1_CBOW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (4.64.1)

# %%
import multiprocessing
import tensorflow as tf
import sys
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Embedding, Lambda
from keras.utils import np_utils
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from textblob import TextBlob, Word
from keras_preprocessing.sequence import pad_sequences
import numpy as np
import random
import os
import pandas as pd
import gensim
import warnings
import nltk

TRACE = False
embedding_dim = 50
epochs=100
batch_size = 500
BATCH = True

def set_seeds_and_trace():
  os.environ['PYTHONHASHSEED'] = '0'
  np.random.seed(42)
  tf.random.set_seed(42)
  random.seed(42)
  if TRACE:
    tf.debugging.set_log_device_placement(True)

def set_session_with_gpus_and_cores():
  cores = multiprocessing.cpu_count()
  gpus = len(tf.config.list_physical_devices('GPU'))
  config = tf.compat.v1.ConfigProto( device_count = {'GPU': gpus  , 'CPU': cores} , intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
  sess = tf.compat.v1.Session(config=config)
  tf.compat.v1.keras.backend.set_session(sess)

set_seeds_and_trace()
set_session_with_gpus_and_cores()
warnings.filterwarnings('ignore')
nltk.download('punkt')
tokenizer = lambda x: TextBlob(x).words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# %%writefile get_data.sh
# if [ ! -f yelp.csv ]; then
#   wget -O yelp.csv https://www.dropbox.com/s/xds4lua69b7okw8/yelp.csv?dl=0
# fi
# Out:
# Overwriting get_data.sh

# %%
# !bash get_data.sh

# %%
path = './yelp.csv'
yelp = pd.read_csv(path).sample(n=1000)
# Create a new DataFrame that only contains the 5-star and 1-star reviews.
yelp_best_worst = yelp[(yelp.stars==5) | (yelp.stars==1)]
X = yelp_best_worst.text
y = yelp_best_worst.stars.map({1:0, 5:1})

# %%
X
# Out:
# 4684    Brought a friend from Louisiana here.  She say...
# 4742    My husband and I were really, really disappoin...
# 4521    Love this place!  Was in phoenix 3 weeks for w...
# 6363    Great place for a "home office" morning. One o...
# 439     1 star for service, but the food is not ok :( ...
#                               ...
# 9791    I love love this store!! Their reduced fat chi...
# 9989    Great food and service! Country food at its best!
# 9965    Treats: We tried the cookies (chocolate chip a...
# 3921                                        Great service
# 6685    Heather is awesome. She did my initial set of ...
# Name: text, Length: 397, dtype: object

# %%
corpus = [sentence for sentence in X.values if type(sentence) == str and len(tokenizer(sentence)) > 3]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
tokenized_corpus = tokenizer.texts_to_sequences(corpus)
print(corpus[3])
print(tokenized_corpus[3])
# Out:
# Great place for a "home office" morning. One of my favorite places - indoor & outdoor seating. Always busy - they offer breakfast & lunch, their food is awesome! Very generous portions.
# [29, 25, 10, 4, 149, 597, 316, 47, 6, 12, 134, 222, 2683, 1835, 547, 64, 478, 18, 363, 297, 150, 41, 27, 7, 132, 39, 972, 417]

# %%
nb_samples = sum(len(s) for s in tokenized_corpus)
vocab_size = len(tokenizer.word_index) + 1

# %%
print(f'First 5 corpus items are {tokenized_corpus[:5]}')
print(f'Length of corpus is {len(tokenized_corpus)}')
# Out:
# First 5 corpus items are [[382, 4, 332, 46, 1821, 35, 109, 827, 14, 1, 1822, 2668, 35, 7, 1, 68, 1151, 22, 477, 6, 1821], [12, 313, 2, 3, 30, 62, 62, 235, 17, 55, 133, 24, 1823, 1824, 19, 382, 55, 2669, 2670, 17, 511, 1825, 2671, 1393, 2, 42, 6, 1826, 5, 16, 1, 594, 1394, 595, 24, 1, 594, 1394, 736, 333, 57, 341, 23, 15, 147, 1827, 1, 2672, 966, 101, 967, 1, 334, 34, 40, 166, 19, 50, 4, 596, 14, 1, 334, 512, 4, 449, 102, 594, 1394, 1828, 72, 73, 968, 105, 2673, 19, 2674, 41, 1395, 597, 5, 1396, 5, 50, 61, 57, 40, 6, 1, 968, 828, 657, 5, 1, 383, 14, 53, 4, 171, 1829, 2, 1, 334, 7, 511, 42, 6, 1826, 19, 30, 969, 42, 2675, 543, 19, 30, 2676, 1, 171, 1829, 2, 258, 5, 384, 1, 334, 5, 4, 198, 2677, 228, 72, 58, 50, 4, 171, 737, 186, 544, 314, 10, 4, 658, 970, 2678, 42, 1, 1828, 45, 22, 4, 1830, 49, 6, 1831, 2, 2679, 2, 513, 5, 32, 1832, 42, 545, 45, 105, 546, 450, 19, 30, 20, 55, 137, 3, 158, 11, 39, 385, 5, 416, 14, 1823, 187, 87, 13, 8, 1, 738, 19, 21, 128, 1152, 10, 4, 102, 2680, 2, 58, 26, 32, 1833, 1824, 89, 2681], [48, 13, 25, 8, 9, 113, 177, 514, 10, 229, 829, 35, 177, 153, 1, 1834, 148, 7, 94, 18, 63, 16, 188, 2682, 2, 971, 6, 129, 315, 259, 78], [29, 25, 10, 4, 149, 597, 316, 47, 6, 12, 134, 222, 2683, 1835, 547, 64, 478, 18, 363, 297, 150, 41, 27, 7, 132, 39, 972, 417], [199, 544, 10, 56, 23, 1, 27, 7, 26, 479, 18, 973, 335, 223, 830, 6, 114, 20, 12, 974, 3, 336, 14, 44, 1836, 8, 4, 1397, 43, 3, 106, 172, 154, 198, 598, 280, 2684, 103, 5, 77, 245, 3, 58, 26, 32, 95, 52]]
# Length of corpus is 394

# %%
type(tokenized_corpus)
# Out:
# list

# %%
def generate_data(corpus, vocab_size, window_size=2, sentence_batch_size=15,  batch_size=250):
    np.random.shuffle(np.array(corpus))
    number_of_sentence_batches = (len(corpus) // sentence_batch_size) + 1
    for batch in range(number_of_sentence_batches):
        lower_end = batch*batch_size
        upper_end = (batch+1)*batch_size if batch+1 < number_of_sentence_batches else len(corpus)
        mini_batch_size = upper_end - lower_end
        maxlen = window_size*2
        X = []
        Y = []
        for review_id, words in enumerate(corpus[lower_end:upper_end]):
            L = len(words)
            for index, word in enumerate(words):
                contexts = []
                labels   = []
                s = index - window_size
                e = index + window_size + 1

                contexts.append([words[i] for i in range(s, e) if 0 <= i < L and i != index])
                labels.append(word)

                x = pad_sequences(contexts, maxlen=maxlen)
                y = np_utils.to_categorical(labels, vocab_size)
                X.append(x)
                Y.append(y)
        X = tf.constant(X)
        Y = tf.constant(Y)
        number_of_batches = len(X) // batch_size
        for real_batch in range(number_of_batches):
          lower_end = batch*batch_size
          upper_end = (batch+1)*batch_size
          batch_X = tf.squeeze(X[lower_end:upper_end])
          batch_Y = tf.squeeze(Y[lower_end:upper_end])
          yield (batch_X, batch_Y)

# %%
cbow = Sequential()
cbow.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=4))
cbow.add(Lambda(lambda x: K.mean(x, axis=1), output_shape=(embedding_dim,)))
cbow.add(Dense(vocab_size, activation='softmax'))
cbow.compile(loss='categorical_crossentropy', optimizer='adam')
cbow.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 4, 50)             279100
#
#  lambda_1 (Lambda)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 5582)              284682
#
# =================================================================
# Total params: 563,782
# Trainable params: 563,782
# Non-trainable params: 0
# _________________________________________________________________

# %%
def fit_model():
    if not BATCH:
        X, Y = generate_data(corpus=tokenized_corpus, vocab_size=vocab_size, batch_size=len(corpus))
        print(f'Size of X is {X.shape} and Y is {Y.shape}')
        cbow.fit(X, Y, epochs = epochs)
    else:
        index = 1
        for x, y in generate_data(corpus=tokenized_corpus, vocab_size=vocab_size, batch_size=batch_size):
            print(f'Training on Iteration: {index}')
            index += 1
            history = cbow.train_on_batch(x, y, reset_metrics=False, return_dict=True)
            print(history)
            if index > epochs:
                break

# %%
fit_model()
# Out:
# Training on Iteration: 1
# {'loss': 8.627424240112305}
# Training on Iteration: 2
# {'loss': 8.626164436340332}
# Training on Iteration: 3
# {'loss': 8.624893188476562}
# Training on Iteration: 4
# {'loss': 8.623615264892578}
# Training on Iteration: 5
# {'loss': 8.622329711914062}
# Training on Iteration: 6
# {'loss': 8.621036529541016}
# Training on Iteration: 7
# {'loss': 8.619735717773438}
# Training on Iteration: 8
# {'loss': 8.618424415588379}
# Training on Iteration: 9
# {'loss': 8.617103576660156}
# Training on Iteration: 10
# {'loss': 8.61577033996582}
# Training on Iteration: 11
# {'loss': 8.614423751831055}
# Training on Iteration: 12
# {'loss': 8.613062858581543}
# Training on Iteration: 13
# {'loss': 8.611684799194336}
# Training on Iteration: 14
# {'loss': 8.61029052734375}
# Training on Iteration: 15
# {'loss': 8.60887622833252}
# Training on Iteration: 16
# {'loss': 8.607440948486328}
# Training on Iteration: 17
# {'loss': 8.605984687805176}
# Training on Iteration: 18
# {'loss': 8.604503631591797}
# Training on Iteration: 19
# {'loss': 8.602996826171875}
# Training on Iteration: 20
# {'loss': 8.601463317871094}
# Training on Iteration: 21
# {'loss': 8.59990119934082}
# Training on Iteration: 22
# {'loss': 8.598308563232422}
# Training on Iteration: 23
# {'loss': 8.596683502197266}
# Training on Iteration: 24
# {'loss': 8.595024108886719}
# Training on Iteration: 25
# {'loss': 8.593328475952148}
# Training on Iteration: 26
# {'loss': 8.591596603393555}
# Training on Iteration: 27
# {'loss': 8.589823722839355}
# Training on Iteration: 28
# {'loss': 8.58800983428955}
# Training on Iteration: 29
# {'loss': 8.586152076721191}
# Training on Iteration: 30
# {'loss': 8.584249496459961}
# Training on Iteration: 31
# {'loss': 8.58229923248291}
# Training on Iteration: 32
# {'loss': 8.580299377441406}
# Training on Iteration: 33
# {'loss': 8.578248977661133}
# Training on Iteration: 34
# {'loss': 8.57614517211914}
# Training on Iteration: 35
# {'loss': 8.573986053466797}
# Training on Iteration: 36
# {'loss': 8.571767807006836}
# Training on Iteration: 37
# {'loss': 8.569491386413574}
# Training on Iteration: 38
# {'loss': 8.567152976989746}
# Training on Iteration: 39
# {'loss': 8.564750671386719}
# Training on Iteration: 40
# {'loss': 8.56228256225586}
# Training on Iteration: 41
# {'loss': 8.559745788574219}
# Training on Iteration: 42
# {'loss': 8.557140350341797}
# Training on Iteration: 43
# {'loss': 8.554461479187012}
# Training on Iteration: 44
# {'loss': 8.551709175109863}
# Training on Iteration: 45
# {'loss': 8.548879623413086}
# Training on Iteration: 46
# {'loss': 8.545971870422363}
# Training on Iteration: 47
# {'loss': 8.542984008789062}
# Training on Iteration: 48
# {'loss': 8.539913177490234}
# Training on Iteration: 49
# {'loss': 8.536758422851562}
# Training on Iteration: 50
# {'loss': 8.533516883850098}
# Training on Iteration: 51
# {'loss': 8.530186653137207}
# Training on Iteration: 52
# {'loss': 8.526765823364258}
# Training on Iteration: 53
# {'loss': 8.523252487182617}
# Training on Iteration: 54
# {'loss': 8.519645690917969}
# Training on Iteration: 55
# {'loss': 8.51594066619873}
# Training on Iteration: 56
# {'loss': 8.512138366699219}
# Training on Iteration: 57
# {'loss': 8.508235931396484}
# Training on Iteration: 58
# {'loss': 8.504231452941895}
# Training on Iteration: 59
# {'loss': 8.500123977661133}
# Training on Iteration: 60
# {'loss': 8.49591064453125}
# Training on Iteration: 61
# {'loss': 8.49159049987793}
# Training on Iteration: 62
# {'loss': 8.487161636352539}
# Training on Iteration: 63
# {'loss': 8.482622146606445}
# Training on Iteration: 64
# {'loss': 8.477971076965332}
# Training on Iteration: 65
# {'loss': 8.47320556640625}
# Training on Iteration: 66
# {'loss': 8.468324661254883}
# Training on Iteration: 67
# {'loss': 8.463327407836914}
# Training on Iteration: 68
# {'loss': 8.458211898803711}
# Training on Iteration: 69
# {'loss': 8.452977180480957}
# Training on Iteration: 70
# {'loss': 8.447622299194336}
# Training on Iteration: 71
# {'loss': 8.442145347595215}
# Training on Iteration: 72
# {'loss': 8.436544418334961}
# Training on Iteration: 73
# {'loss': 8.430819511413574}
# Training on Iteration: 74
# {'loss': 8.424968719482422}
# Training on Iteration: 75
# {'loss': 8.418992042541504}
# Training on Iteration: 76
# {'loss': 8.412886619567871}
# Training on Iteration: 77
# {'loss': 8.406652450561523}
# Training on Iteration: 78
# {'loss': 8.400289535522461}
# Training on Iteration: 79
# {'loss': 8.393795013427734}
# Training on Iteration: 80
# {'loss': 8.38716983795166}
# Training on Iteration: 81
# {'loss': 8.380414009094238}
# Training on Iteration: 82
# {'loss': 8.373523712158203}
# Training on Iteration: 83
# {'loss': 8.366500854492188}
# Training on Iteration: 84
# {'loss': 8.359344482421875}
# Training on Iteration: 85
# {'loss': 8.35205364227295}
# Training on Iteration: 86
# {'loss': 8.34462833404541}
# Training on Iteration: 87
# {'loss': 8.337068557739258}
# Training on Iteration: 88
# {'loss': 8.329374313354492}
# Training on Iteration: 89
# {'loss': 8.321544647216797}

# %%
with open('./cbow_scratch_synonims.txt' ,'w') as f:
    f.write('{} {}\n'.format(vocab_size-1, embedding_dim))
    vectors = cbow.get_weights()[0]
    for word, i in tokenizer.word_index.items():
        str_vec = ' '.join(map(str, list(vectors[i, :])))
        f.write('{} {}\n'.format(word, str_vec))

# %%
w2v = gensim.models.KeyedVectors.load_word2vec_format('./cbow_scratch_synonims.txt', binary=False)

# %%
tokenizer.word_index.keys()
# Out:
# dict_keys(['the', 'and', 'i', 'a', 'to', 'of', 'is', 'was', 'in', 'for', 'it', 'my', 'this', 'that', 'you', 'have', 'with', 'they', 'we', 'on', 'are', 'had', 'but', 'at', 'place', 'not', 'food', 'so', 'great', 'were', 'as', 'be', 'good', 'there', 'here', 'me', 'like', 'if', 'very', 'all', 'their', 'out', 'when', 'go', 'just', 'from', 'one', 'love', 'up', 'get', 'your', 'back', "it's", 'been', 'our', 'service', 'or', 'will', 'about', 'can', 'some', 'really', 'also', 'always', 'an', 'time', 'what', 'best', 'by', "i've", 'has', 'which', 'would', "don't", 'them', 'got', 'no', 'try', 'do', 'well', 'staff', 'even', 'only', 'never', 'us', 'more', 'know', 'too', 'how', 'he', 'because', 'friendly', 'first', 'amazing', 'going', "i'm", 'off', 'restaurant', 'then', 'menu', 'after', 'new', 'little', 'made', 'over', 'went', 'fresh', 'nice', 'she', 'people', 'delicious', 'am', 'phoenix', 'chicken', 'where', 'ever', 'right', 'who', 'make', 'any', 'every', 'few', 'everything', "can't", 'much', 'say', 'did', 'now', 'other', 'bar', 'see', 'awesome', 'experience', 'favorite', 'wait', 'her', 'way', 'happy', 'sure', 'order', 'since', '2', 'definitely', 'around', 'dinner', 'come', 'could', 'salad', 'home', 'lunch', 'another', 'night', 'times', 'ordered', 'before', 'take', 'eat', 'find', 'than', 'prices', 'sauce', 'came', 'last', 'table', 'want', 'day', 'thing', 'worth', 'many', 'years', 'big', 'again', 'area', 'down', 'tried', 'cheese', '3', 'pretty', 'location', 'perfect', 'feel', 'lot', 'meal', 'pizza', 'next', '5', "didn't", 'sushi', 'most', 'something', 'better', 'two', 'coffee', 'probably', 'into', 'town', 'store', 'different', '1', 'took', 'without', 'things', 'excellent', 'recommend', 'atmosphere', 'hour', 'visit', '10', 'clean', 'kids', 'still', 'drinks', 'top', 'its', 'asked', 'his', 'should', 'think', 'business', 'wonderful', 'while', 'places', '4', 'said', 'side', 'check', 'stars', 'shop', 'work', 'through', 'getting', 'valley', 'looking', 'each', 'disappointed', "wasn't", 'special', 'walk', 'absolutely', 'family', 'bread', 'use', 'both', 'price', 'meat', "that's", 'bad', 'especially', 'long', 'roll', 'once', 'cool', 'though', 'fun', 'these', 'give', 'those', 'decided', 'must', 'flavor', 'fantastic', 'bit', 'dish', 'taste', 'far', 'enough', 'friends', "you're", 'need', 'selection', 'free', 'tasty', 'burger', 'old', 'tea', 'hair', 'wine', 'inside', 'beer', 'same', '20', 'huge', 'almost', 'during', 'being', 'small', 'market', 'fish', 'such', 'week', 'beautiful', 'quite', 'full', 'care', 'oh', 'cake', 'breakfast', 'already', 'shrimp', 'couple', 'away', 'high', 'beef', 'drive', 'name', 'highly', 'found', 'sweet', 'super', 'part', 'actually', 'everyone', 'husband', 'review', 'items', 'morning', 'walked', 'minutes', 'fries', 'trip', 'rice', 'thought', 'nothing', 'anything', 'usually', 'room', 'else', 'drink', 'sandwich', 'buy', 'parking', 'friend', 'open', 'car', 'put', 'let', 'customer', 'style', 'server', 'year', 'close', 'enjoy', 'someone', 'house', 'live', 'hot', 'told', 'does', 'having', 'sunday', 'attentive', 'comfortable', 'decor', 'hours', 'unique', 'thank', 'restaurants', 'yelp', 'mexican', 'tell', 'look', 'chinese', 'offer', 'music', 'able', 'dishes', 'used', "doesn't", '8', 'stuff', 'cooked', '6', 'doing', "i'll", 'soup', 'wanted', 'spicy', 'large', 'stay', 'door', 'why', 'brought', 'fact', 'bring', 'hard', 'overall', 'help', 'sit', 'front', 'helpful', 'dining', 'person', 'eaten', 'tasted', 'street', "i'd", 'quick', 'stop', 'under', 'makes', '30', 'life', '15', 'thanks', 'wrong', 'ago', 'finally', 'scottsdale', 'owner', 'fan', 'kind', 'etc', 'fast', 'theater', 'guy', 'believe', 'portions', 'water', 'wish', 'tables', 'spot', 'quality', 'extremely', 'three', 'school', 'saw', 'mean', 'simply', 'ask', 'bite', 'gave', 'guys', 'trying', 'fried', 'red', 'money', 'job', 'cut', 'keep', 'real', 'loved', 'hotel', 'weekend', 'several', 'left', 'myself', 'pool', 'bbq', 'whole', 'later', 'itself', 'often', 'wow', 'own', 'variety', 'today', 'done', ...

# %%
w2v.most_similar(positive=['mcdonalds'])
# Out:
# [('pasties', 0.4654390811920166),
#  ('wrap', 0.4574213922023773),
#  ('cut', 0.45387741923332214),
#  ('related', 0.44767501950263977),
#  ('lamb', 0.44436410069465637),
#  ('worthy', 0.4310397505760193),
#  ('trusted', 0.41768014430999756),
#  ('dept', 0.417471319437027),
#  ('condos', 0.41663089394569397),
#  ('locker', 0.39296430349349976)]

# %%
w2v.most_similar(negative=['apple'])
